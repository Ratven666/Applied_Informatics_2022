# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задачи-на-чтение-и-парсинг-файлов" data-toc-modified-id="Задачи-на-чтение-и-парсинг-файлов-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задачи на чтение и парсинг файлов</a></span><ul class="toc-item"><li><span><a href="#Задача-8.1.1-$\star$" data-toc-modified-id="Задача-8.1.1-$\star$-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Задача 8.1.1 $\star$</a></span></li><li><span><a href="#Задача-8.1.2-$\star$" data-toc-modified-id="Задача-8.1.2-$\star$-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Задача 8.1.2 $\star$</a></span></li><li><span><a href="#Задача-8.2-$\star$" data-toc-modified-id="Задача-8.2-$\star$-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Задача 8.2 $\star$</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Задачи на чтение и парсинг файлов

# %% [markdown]
# ## Задача 8.1.1 $\star$
#
# В текстовом файле ```GNSS_Base_SPB_MSK_64.txt```, находящемся в папке ```src\Task_8_1```, содержится информация о положении некоторых референцных базовых станций на территориии Санкт-Петербурга.
#
# Даннные в файле записаны в соответствии со следующей структурой:

# %% [markdown]
# ![GNSS_part.jpg](attachment:GNSS_part.jpg)

# %% [markdown]
# ### **ЗАДАНИЕ:**
#
# * Прочитайте файл ```GNSS_Base_SPB_MSK_64.txt```.
#
# > *Подсказка* для нормального отображения кириллических символов укажите явно кодировку файла:
# ```python
# with open( ... , ... , encoding="UTF-8") as file:
# ```
#
# * Разберитесь со структурой каждой строки (какие разделители, какие данные в файле существенны и тп)
#
# * Создайте список ```gnss_spb_msk_64_lst```, содержащий в себе кортежи со следующей структурой:
# ```python
# [(ID: str, RTCM_ID: int, X: float, Y: float, X: float),
#  ...]
# ```
# * Выведите получившийся результат наглядно в консоль.

# %% [markdown]
# #### Примерный результат
#
# **(Перенос на новые строки сделан для наглядности):**
#
# ```python
# [("AGLT", 1015, 124427.953, 110155.593,  68.591),
#  ("BNTA", 1002, 92773.190, 111812.361, 23.412),
#  ....
# ]
# ```

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Задача 8.1.2 $\star$
#
# В текстовом файле ```GNSS_Base_SPB_MSK_64.txt```, находящемся в папке ```src\Task_8_1```, содержится информация о положении некоторых референцных базовых станций на территориии Санкт-Петербурга.
#
# Даннные в файле записаны в соответствии со следующей структурой:

# %% [markdown]
# ### **ЗАДАНИЕ:**
#
# * Прочитайте файл ```GNSS_Base_SPB_MSK_64.txt```.
#
# > *Подсказка* для нормального отображения кириллических символов укажите явно кодировку файла:
# ```python
# with open( ... , ... , encoding="UTF-8") as file:
# ```
#
# * Разберитесь со структурой каждой строки (какие разделители, какие данные в файле существенны и тп)
#
# * Создайте словарь ```gnss_spb_msk_64``` со следующей структурой:
# ```python
# {"ID": {"rtcm_id": int,
#         "position": {"x": float,
#                      "y": float,
#                      "z": float}}
# }
# ```
# * Выведите получившийся результат наглядно в консоль.

# %% [markdown]
# #### Примерный результат
#
# **(Отступы и перенос на новые строки сделаны для наглядности):**
#
# ```python
# {"AGLT": {"rtcm_id": 1015,
#         "position": {"x": 124427.953,
#                      "y": 110155.593,
#                      "z": 68.591}},
#  "BNTA": {"rtcm_id": 1002,
#         "position": {"x": 92773.190,
#                      "y": 111812.361,
#                      "z": 23.412}},
#  ...
# }
# ```

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Задача 8.2.1 $\star$
#
# На сайте [GEOBRIDGE](https://geobridge.ru/netrbs) можно найти много информации о сетях референцных базовых станций в СПб и России.
#
# Для примера просмотрим информацию о сети станций на территории Санкт-Петербурга и Ленинградской области "Геоспайдер".

# %% [markdown]
# ![%D0%A2%D0%BE%D1%87%D0%B5%D1%87%D0%BD%D1%8B%D0%B9%20%D1%80%D0%B8%D1%81%D1%83%D0%BD%D0%BE%D0%BA.bmp](attachment:%D0%A2%D0%BE%D1%87%D0%B5%D1%87%D0%BD%D1%8B%D0%B9%20%D1%80%D0%B8%D1%81%D1%83%D0%BD%D0%BE%D0%BA.bmp)

# %% [markdown]
# Данные о базовых станциях [ГЕОСПАЙДЕР](https://geobridge.ru/netrbs/net/geospider) представленны в виде:

# %% [markdown]
# ![GNSS_Geospider.jpg](attachment:GNSS_Geospider.jpg)

# %% [markdown]
# В текстовом файле ```GNSS_Base_GEOSPIDER_FULL.txt```, находящемся в папке ```src\Task_8_2```, содержится информация, скопированная из всей этой таблицы.
#
# Даннные в файле записаны в соответствии со следующей структурой:

# %% [markdown]
# ![GNSS_Geospider_TXT.jpg](attachment:GNSS_Geospider_TXT.jpg)

# %% [markdown]
# Из представленной ниже иллюстрации видно, что данные перенеслись в несколько нарушенной структуре, но все соответствия между данными в файле и таблице сопоставить не сложно:

# %% [markdown]
# ![GNSS_Geospider_Struct.jpg](attachment:GNSS_Geospider_Struct.jpg)

# %% [markdown]
# ### **ЗАДАНИЕ:**
#
# * Прочитайте файл ```GNSS_Base_GEOSPIDER_FULL.txt```.
#
# > *Подсказка* для нормального отображения кириллических символов укажите явно кодировку файла:
# ```python
# with open( ... , ... , encoding="UTF-8") as file:
# ```
#
# * Разберитесь со структурой каждой строки (какие разделители, какие данные в файле существенны и тп)
#
# * Создайте словарь ```gnss_geospider``` со следующей структурой:
# ```python
# {"name": {"rtcm_id": str,
#          "antenna": {"manufacturer": str,
#                      "model": str,
#                      "serial number": str},
#          "receiver": {"manufacturer": str,
#                      "model": str,
#                      "serial number": str,
#                      "code": str},
#          "status": {"is_active": str,
#                     "date" : str,
#                     "time": str},
#          "position": {"B": str,
#                       "L": str,
#                       "H": str,
#                       "coordinate system": str}
#         }
#  ...
# }
# ```
# * Выведите получившийся результат наглядно в консоль.

# %% [markdown]
# #### Примерный результат
#
# **(Отступы и перенос на новые строки сделаны для наглядности):**
#
# ```python
# gnss_geospider = {"53VN": {"rtcm_id": "1028",
#                          "antenna": {"manufacturer": "Trimble",
#                                      "model": "TRM57971.00 NONE",
#                                      "serial number": "1441138026"},
#                          "receiver": {"manufacturer": "Геоспайдер",
#                                      "model": "GEOSPIDER BS",
#                                      "serial number": "100048",
#                                      "code": "5.54"},
#                          "status": {"is_active": "Работает",
#                                     "date" : "17.08.22",
#                                     "time": "04:42:28"},
#                          "position": {"B": "58°30'35.59847" N",
#                                       "L": "31°14'30.48629" E",
#                                       "H": "54.085 м",
#                                       "coordinate system": "ITRF2008 2013.05.23"}
#                         },
#                  {"60V2": {"rtcm_id": "1118",
#                          "antenna": {"manufacturer": "Topcon",
#                                      "model": "TPSCR.G5 TPSH",
#                                      "serial number": "76212883"},
#                          "receiver": {"manufacturer": "Topcon",
#                                      "model": "TPS NET-G5",
#                                      "serial number": "1294-11857",
#                                      "code": "5.2.6 May,08,2020"},
#                          "status": {"is_active": "Работает",
#                                     "date" : "19.08.22",
#                                     "time": "13:48:28"},
#                          "position": {"B": "56°20'15.05846" N",
#                                       "L": "30°30'02.97030" E",
#                                       "H": "135.715 м",
#                                       "coordinate system": "ITRF2008 2013.05.23"}
#                         },
#                  ...
#                 }
# ```

# %% [markdown]
# > **Подсказка** Не пытайтесь сразу прочитать весь файл!
# - Сначала разберитесь в его структуре;
# - Попробуйте создать нужную структуру данных для первого приемника (данные для него скопированны в файл ```GNSS_Base_GEOSPIDER_1.txt```
# - Потом попробуйте перенести свое решение на файл с пятью приемниками (```GNSS_Base_GEOSPIDER_5.txt```)
# - Если все успешно переходите к файлу целиком.

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Задача 8.2.2 $\star$
#
# В сформированном при решении задачи 8.2.1 словаре ```gnss_geospider``` отформатируйте строки данных в соответствии с их содержанием, приведите получившиеся данные к нужным типам.

# %% [markdown]
# #### Примерный результат
#
# **(Отступы и перенос на новые строки сделаны для наглядности):**
#
# ```python
# gnss_geospider = {"53VN": {"rtcm_id": 1028,
#                          "antenna": {"manufacturer": "Trimble",
#                                      "model": "TRM57971.00 NONE",
#                                      "serial number": "1441138026"},
#                          "receiver": {"manufacturer": "Геоспайдер",
#                                      "model": "GEOSPIDER BS",
#                                      "serial number": "100048",
#                                      "code": "5.54"},
#                          "status": {"is_active": True,
#                                     "date" : "17.08.22",
#                                     "time": "04:42:28"},
#                          "position": {"B": 58.50988846,
#                                       "L": 31.24180175,
#                                       "H": 54.085,
#                                       "coordinate system": "ITRF2008 2013.05.23"}
#                         },
#                  {"60V2": {"rtcm_id": 1118,
#                          "antenna": {"manufacturer": "Topcon",
#                                      "model": "TPSCR.G5 TPSH",
#                                      "serial number": "76212883"},
#                          "receiver": {"manufacturer": "Topcon",
#                                      "model": "TPS NET-G5",
#                                      "serial number": "1294-11857",
#                                      "code": "5.2.6 May,08,2020"},
#                          "status": {"is_active": True,
#                                     "date" : "19.08.22",
#                                     "time": "13:48:28"},
#                          "position": {"B": 56.33751624,
#                                       "L": 30.50082508,
#                                       "H": 135.715,
#                                       "coordinate system": "ITRF2008 2013.05.23"}
#                         },
#                  ...
#                 }
# ```

# %% [markdown]
# > **ДОПОЛНИТЕЛЬНО**
#
# ```python
#                          "status": {"is_active": True,
#                                     "date" : 17.08.22 - date,
#                                     "time": 04:42:28 - time},
#
# ```
#
# > Для создания даты и времени, с кторомыми можно будет потом удобно работать, можно воспользоваться встренным модулем ```datetime```
#
# * Выведите получившийся результат наглядно в консоль.

# %% [markdown]
# ***
# ***
