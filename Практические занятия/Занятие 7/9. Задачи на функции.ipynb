# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задачи-на-функции" data-toc-modified-id="Задачи-на-функции-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задачи на функции</a></span></li><li><span><a href="#Задача-9" data-toc-modified-id="Задача-9-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задача 9</a></span><ul class="toc-item"><li><span><a href="#Задача-9.1-$\star$" data-toc-modified-id="Задача-9.1-$\star$-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Задача 9.1 $\star$</a></span><ul class="toc-item"><li><span><a href="#ЗАДАНИЕ:" data-toc-modified-id="ЗАДАНИЕ:-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span><strong>ЗАДАНИЕ:</strong></a></span></li></ul></li><li><span><a href="#Задача-9.2-$\star$" data-toc-modified-id="Задача-9.2-$\star$-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Задача 9.2 $\star$</a></span><ul class="toc-item"><li><span><a href="#Задача-9.2.1-$\star$" data-toc-modified-id="Задача-9.2.1-$\star$-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Задача 9.2.1 $\star$</a></span><ul class="toc-item"><li><span><a href="#ЗАДАНИЕ:" data-toc-modified-id="ЗАДАНИЕ:-2.2.1.1"><span class="toc-item-num">2.2.1.1&nbsp;&nbsp;</span><strong>ЗАДАНИЕ:</strong></a></span></li></ul></li><li><span><a href="#Задача-9.2.2" data-toc-modified-id="Задача-9.2.2-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Задача 9.2.2</a></span><ul class="toc-item"><li><span><a href="#ЗАДАНИЕ:" data-toc-modified-id="ЗАДАНИЕ:-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span><strong>ЗАДАНИЕ:</strong></a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Задачи на функции

# %% [markdown]
# # Задача 9
#
# В файле ```Общий_план_М_1_500.dwg``` (формат 2004 года), находящемся в папке ```.\src\```, содержится информация о батиметрической съемке морсокго дна и контурах двух участков работ по дноуглублению.
#
# Общий вид проекта:

# %% [markdown]
# ![%D0%9E%D0%B1%D1%89%D0%B8%D0%B9%20%D0%B2%D0%B8%D0%B4.jpg](attachment:%D0%9E%D0%B1%D1%89%D0%B8%D0%B9%20%D0%B2%D0%B8%D0%B4.jpg)

# %% [markdown]
# ## Задача 9.1 $\star$
#
# В  папке ```.\src\Task_9_1```, содержится результат батиметрической съемки в районе дноуглубительных работ.
#
# Общий вид файла ```Исходная батиметрия.dwg```:

# %% [markdown]
# ![%D0%91%D0%B0%D1%82%D0%B8%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%8F%201.jpg](attachment:%D0%91%D0%B0%D1%82%D0%B8%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%8F%201.jpg)

# %% [markdown]
# **Проблема в том, что точки в файле записаны не корректно - для автоматической генерации подписи отметок в качестве высот точек были записаны положительные, а не отрицательные числа.**

# %% [markdown]
# ![%D0%91%D0%B0%D1%82%D0%B8%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%8F%202.jpg](attachment:%D0%91%D0%B0%D1%82%D0%B8%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%8F%202.jpg)

# %% [markdown]
# В текстовом файле ```Исходная батиметрия.txt```, находящемся в папке ```.\src\Task_9_1```, содержится информация о положении точек дна, извлеченная из ```.dwg``` файла.
#
# Даннные в файле записаны в соответствии со следующей структурой:

# %% [markdown]
# ![%D0%91%D0%B0%D1%82%D0%B8%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%8F%203.jpg](attachment:%D0%91%D0%B0%D1%82%D0%B8%D0%BC%D0%B5%D1%82%D1%80%D0%B8%D1%8F%203.jpg)

# %% [markdown]
# ### **ЗАДАНИЕ:**
#
# > **Необходимо исправить отметки точек на отрицательные значения и подготовить файл к удобному экспорту в ```AutoCAD```.**
#
# **Для этого**
#
# 1. *Напишите функцию которая принимает путь до файла и возвращает список прочитанных точек.*
#
# * Прочитайте файл ```Исходная батиметрия.txt```.
# * Разберитесь со структурой каждой строки (какие разделители, какие данные в файле существенны и тп)
#
# * Создайте функцию ```parse_autocad_points_txt_file```, принимающую в качестве обязательного аргумента путь до файла и возвращающую список со следующей структурой:
# ```python
# [[555763.000, 5031304.000, 13.900],
#  [555779.000, 5031289.000, 13.900],
#  ...]
# ```
# * Выведите наглядно в консоль первые 20 строчек получившегося результата.

# %% [markdown]
# 2. *Напишите функцию ```reverse_elevation_ marks``` которая принимает ранее сформированный список точек и возвращает список с отметками в которых изменен знак.*
#
# * Создайте функцию, принимающую в качестве обязательного аргумента список со следующей структурой:
# ```python
# [[555763.000, 5031304.000, 13.900],
#  [555779.000, 5031289.000, 13.900],
#  ...]
# ```
# * Функция должна вернуть список со следующей структурой:
# ```python
# [[555763.000, 5031304.000, -13.900],
#  [555779.000, 5031289.000, -13.900],
#  ...]
# ```
# * Выведите наглядно в консоль первые 20 строчек получившегося результата.

# %% [markdown]
# 3. *Напишите функцию ```export_acad_point_file``` которая принимает список точек и создает файл который можно скопировать в ```AutoCad```.*
#
# * Создайте функцию, принимающую в качестве обязательного аргумента имя создаваемого файла и список со следующей структурой:
# ```python
# [[555763.000, 5031304.000, -13.900],
#  [555779.000, 5031289.000, -13.900],
#  ...]
# ```
# * Откройте создаваемый файл для записи (подумайте какой режим записи будет оптимальным)
#
# * Запишите в файл данные в следующем виде:
#
# ``` python
# _point
# 505408.0,4881290.0,-15.1
# _point
# 505409.0,4881286.0,-15.3
# _point
# 505409.0,4881282.0,-15.8
# _point
# 505409.0,4881278.0,-16.0
# ...
# ```

# %% [markdown]
# > *ДОПОЛНИТЕЛЬНО*
#
# A. *Скопируйте получившийся файл в командную строку ```AutoCad``` и проверьте получившийся результат.*
#
# B. *Вы же догадались сами, что "Выведите наглядно в консоль первые 20 строчек получившегося результата." разумно добиваться с помошью функции?...*

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Задача 9.2 $\star$
#
# В  папке ```.\src\Task_9_2```, содержится информация о контурах участков дноуглубительных работ. Тонкими красными и зелеными полилиниями обозначены зоны в которых непосредственно необходимо провести дноуглубительные работы.
#
# Общий вид файла ```Общий контур работ.dwg```:

# %% [markdown]
# ![%D0%9A%D0%BE%D0%BD%D1%82%D1%83%D1%80%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%20%D0%BE%D0%B1%D1%89%D0%B8%D0%B9.jpg](attachment:%D0%9A%D0%BE%D0%BD%D1%82%D1%83%D1%80%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%20%D0%BE%D0%B1%D1%89%D0%B8%D0%B9.jpg)

# %% [markdown]
# Для создания задания землесосной машины необходимо получить упорядоченный список точек, определяющих вершины контура дноуглубления.
#
# Начальная точка полигона может быть выбрана произвольно, как и его направление (по или против часовой стрелки), но важно, чтобы при последовательном соединении точек в списке получаемая фигура была тождествена исходной.

# %% [markdown]
# ### Задача 9.2.1 $\star$
#
# В  папке ```.\src\Task_9_2\Контур работ 1.dwg```, содержится информация о первом контуре дноуглубительных работ.
#
# Общий вид файла ```Контур работ 1.dwg```:

# %% [markdown]
# ![%D0%9A%D0%BE%D0%BD%D1%82%D1%83%D1%80%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%201.jpg](attachment:%D0%9A%D0%BE%D0%BD%D1%82%D1%83%D1%80%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%201.jpg)

# %% [markdown]
# В файле ```.\src\Task_9_2\Контур работ 1.txt```, содержится извлеченная средствами ```AutoCad``` информация о вершинах отрезков, составляющих полилинию.
#
# В задании гарантируется, что каждый отрезок встречается в файле один раз, все отрезки направлены в согласованном направлении и в сумме образуют требуемый контур.
#
# **Порядок следования отрезков в файле может не совпадать с их порядком в полилинии!!!**

# %% [markdown]
# #### **ЗАДАНИЕ:**
#
# > **Необходимо получить упорядоченный список точек, определяющих вершины участка работ, и записать его в текстовый файл.**
#
# 1. *Напишите функцию которая принимает путь до файла и возвращает список прочитанных отрезков.*
#
# * Прочитайте файл ```Контур работ 1.txt```.
# * Разберитесь со структурой каждой строки (какие разделители, какие данные в файле существенны и тп)
#
# * Создайте функцию ```parse_autocad_lines_txt_file```, принимающую в качестве обязательного аргумента путь до файла и возвращающую список со следующей структурой:
# ```python
# [[(555695.388, 5031285.726), (555693.415, 5031283.291)],
#    [(555693.481, 5031287.272), (555695.388, 5031285.726)],
#    ...
# ]
# ```
# * Выведите наглядно в консоль первые 20 строчек получившегося результата.

# %% [markdown]
# 2. *Напишите фукцию ```sort_lines_order```, сортирующую порядок следования отрезков таким образом, чтобы координаты первой точки следующего отрезка совпадали с координатами второй точки предыдущего.*
#
# * Создайте функцию, принимающую в качестве обязательного аргумента список со следующей структурой:
# ```python
# [[(555695.388, 5031285.726), (555693.415, 5031283.291)],
#    [(555693.481, 5031287.272), (555695.388, 5031285.726)],
#    [(555689.041, 5031285.383), (555693.481, 5031287.272)],
#    ...
# ]
# ```
# * Функция должна вернуть список со следующей структурой:
# ```python
# [[(555695.388, 5031285.726), (555693.415, 5031283.291)],
#    [(555693.415, 5031283.291), (555689.332, 5031283.806)],
#    [(555689.332, 5031283.806), (555687.257, 5031282.669)],
#    ...
# ]
# ```
# * Выведите наглядно в консоль первые 20 строчек получившегося результата.

# %% [markdown]
# 3. *Напишите функцию ```create_point_list``` которая принимает упорядоченный список отрезков и возвращает список точек*
#
# * Создайте функцию, принимающую в качестве обязательного аргумента список отрезков со следующей структурой:
# ```python
# [[(555695.388, 5031285.726), (555693.415, 5031283.291)],
#    [(555693.415, 5031283.291), (555689.332, 5031283.806)],
#    [(555689.332, 5031283.806), (555687.257, 5031282.669)],
#    ...
# ]
# ```
# * Функция должна вернуть список точек вида:
#
# ```python
# [(555695.388, 5031285.726),
#  (555693.415, 5031283.291),
#  (555689.332, 5031283.806),
#  ...
# ]
# ```

# %% [markdown]
# 4. *Напишите функцию ```export_point_file``` которая принимает список точек и записывает их в файл.*
#
# * Создайте функцию, принимающую в качестве обязательного аргумента имя создаваемого файла и список со следующей структурой:
# ```python
# [(555695.388, 5031285.726),
#  (555693.415, 5031283.291),
#  (555689.332, 5031283.806),
#  ...
# ]
# ```
# * Откройте создаваемый файл для записи (подумайте какой режим записи будет оптимальным)
#
# * Запишите в файл данные в следующем виде:
#
# ```
#  555695.388\t5031285.726\n
#  555693.415\t5031283.291\n
#  555689.332\t5031283.806\n
#  ...
#
# ```

# %% [markdown]
# 4. *Напишите функцию ```export_acad_polyline_file``` которая принимает список точек и создает файл который можно скопировать в ```AutoCad```.*
#
# * Создайте функцию, принимающую в качестве обязательного аргумента имя создаваемого файла и список со следующей структурой:
# ```python
# [(555695.388, 5031285.726),
#  (555693.415, 5031283.291),
#  (555689.332, 5031283.806),
#  ...
# ]
# ```
# * Откройте создаваемый файл для записи (подумайте какой режим записи будет оптимальным)
#
# * Запишите в файл данные в следующем виде:
#
# ``` python
# _pline
# 555695.388,5031285.726
# 555693.415,5031283.291
# 555689.332,5031283.806
# ...
# ```

# %% [markdown]
# > *ДОПОЛНИТЕЛЬНО*
#
# A. *Скопируйте получившийся файл в командную строку ```AutoCad``` и проверьте получившийся результат.*

# %% [markdown]
# ***
# ***

# %% [markdown]
# ### Задача 9.2.2
#
# В  папке ```.\src\Task_9_2\Контур работ 2.dwg```, содержится информация о втором контуре дноуглубительных работ.
#
# Общий вид файла ```Контур работ 2.dwg```:

# %% [markdown]
# ![%D0%9A%D0%BE%D0%BD%D1%82%D1%83%D1%80%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%202.jpg](attachment:%D0%9A%D0%BE%D0%BD%D1%82%D1%83%D1%80%20%D1%80%D0%B0%D0%B1%D0%BE%D1%82%202.jpg)

# %% [markdown]
# В файле ```.\src\Task_9_2\Контур работ 2.csv```, содержится извлеченная средствами ```AutoCad``` информация о вершинах отрезков, составляющих полилинию.
#
# В задании гарантируется, что каждый отрезок может встречается в файле **БОЛЕЕ ОДНОГО РАЗА**, **ОТРЕЗКИ МОГУТ БЫТЬ НАПРАВЛЕННЫ В РАЗНЫЕ СТОРОНЫ**, **МОГУТ ПРИСУТСТВОВАТЬ ОТРЕЗКИ НУЛЕВОЙ ДЛИННЫ** и в сумме образуют требуемый контур.
#
# **Порядок следования отрезков в файле может не совпадать с их порядком в полилинии!!!**

# %% [markdown]
# #### **ЗАДАНИЕ:**
#
# > **Необходимо адаптировать функции написанные при решении задачи 9.2.1 для случая исходных данных задачи 9.2.2.**

# %% [markdown]
# ***
# ***
