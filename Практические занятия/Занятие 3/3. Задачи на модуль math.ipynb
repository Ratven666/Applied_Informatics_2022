# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задачи-на-модуль-math" data-toc-modified-id="Задачи-на-модуль-math-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задачи на модуль <code>math</code></a></span></li><li><span><a href="#Задача-1" data-toc-modified-id="Задача-1-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задача 1</a></span><ul class="toc-item"><li><span><a href="#Задача-2" data-toc-modified-id="Задача-2-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Задача 2</a></span></li><li><span><a href="#Задача-3" data-toc-modified-id="Задача-3-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Задача 3</a></span></li><li><span><a href="#Задача-4" data-toc-modified-id="Задача-4-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Задача 4</a></span></li><li><span><a href="#Задача-5" data-toc-modified-id="Задача-5-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Задача 5</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Задачи на модуль ```math```

# %%
import ...

# %% [markdown]
# # Задача 3.1 $\star$
#
# Напишите программу для решения прямой и обратной геодезической задачи!
#
# > Посмотрите и используйте максимально подходящие функции модуля ```math```

# %% [markdown]
# ![25.png](attachment:25.png)

# %% [markdown]
# Придумайте и реализуйте тестовые задачи для своего решения, доказывающие его правильность.

# %%
x_a = None
y_a = None

x_b = None
y_b = None

azimut = None
dist = None

# %%
# Прямая геодезическая задача

# %%
# Обратная геодезическая задача

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Задача 3.2.1 $\star$
#
# Треугольник задан плоскими координатами трех вершин. Рассчитайте и выведите в консоль его периметр и площадь.
#
# $$ S = \sqrt{p(p-a)(p-b)(p-c)} $$
# $$ p=\frac{a+b+c}{2} $$
# $ a, b, c $ - стороны треугольника

# %% [markdown]
# Придумайте и реализуйте тестовые задачи для своего решения, доказывающие его правильность.

# %%
x_a = None
y_a = None

x_b = None
y_b = None

x_c = None
y_c = None

# %% [markdown]
# ***

# %% [markdown]
# ## Задача 3.2.2
# Треугольник задан трехмерными координатами трех вершин. Рассчитайте и выведите в консоль его периметр и площадь.
#
# $$ S = \sqrt{p(p-a)(p-b)(p-c)} $$
# $$ p=\frac{a+b+c}{2} $$
# $ a, b, c $ - стороны треугольника

# %% [markdown]
# Придумайте и реализуйте тестовые задачи для своего решения, доказывающие его правильность.

# %%
x_a = None
y_a = None
z_a = None

x_b = None
y_b = None
z_b = None

x_c = None
y_c = None
z_c = None

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Задача 3.3 $\star$
# Заданы координаты трех точек $A, B, C$ и два горизонтальных угла $ \beta_1, \beta_2 $. Рассчитайте по формулам Юнга координаты точки $ P $.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-09-19%20224808-2.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202022-09-19%20224808-2.png)

# %% [markdown]
# $$ \tan(\theta) = \frac{(Y_B - Y_C)\cot\beta_2 - (Y_A - Y_B)\cot\beta_1 + X_C - X_A}{(X_B - X_C)\cot\beta_2 - (X_A - X_B)\cot\beta_1 - Y_C + Y_a} $$
#
# $$ N = (Y_B - Y_C)(\cot\beta_2 - \tan\theta) - (X_B - X_C)(1 + \cot\beta_2\tan\theta) $$
#
# $$ \Delta X = \frac{N}{1 + \tan^2\theta} $$
#
# $$ \Delta Y = \Delta X\tan\theta $$
#
# $$ X_P = X_B + \Delta X $$
#
# $$ Y_P = Y_B + \Delta Y $$

# %%
x_a = None
y_a = None

x_b = None
y_b = None

x_c = None
y_c = None

b_1 = None    # Подумайте над удобством формы задания угла!
b_2 = None

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Задача 3.4 $\star$
#
# Прямая задана координатами двух точек. Выведите уравнение этой прямой в виде: $$ y = kx + b $$

# %% [markdown]
# Придумайте и реализуйте тестовые задачи для своего решения, доказывающие его правильность.

# %%
x_a = None
y_a = None

x_b = None
y_b = None

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Задача 3.5 $\star$
#
# Две прямые заданы координатами двух своих точек ($A-B$ и $C-D$). Вычислите координаты точки их пересечения, если прямые параллельны - выведите в консоль тип ```None```

# %% [markdown]
# Придумайте и реализуйте тестовые задачи для своего решения, доказывающие его правильность.

# %%
x_a = None
y_a = None

x_b = None
y_b = None

x_c = None
y_c = None

x_d = None
y_d = None

# %% [markdown]
# ***
# ***
